# %% [markdown]
# # EDA — Email Spam Dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("../data/emails.csv")
print(df.shape)
display(df.head())
display(df["label"].value_counts())
df["text_length"] = df["text"].str.len()
display(df.groupby("label")["text_length"].describe())

# %% [markdown]
# Use this notebook to document dataset balance, message length, duplicates and representative examples.
